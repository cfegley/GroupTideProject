# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import scipy.stats

from scipy import optimize

#Curve fit function************
def fitCurve(x, A, f, p):
    return A *np.sin(f * x + p)
#****************************** 
    

#We want to bring in the data from the CSV file 
dataArray = np.loadtxt('/Users/ChadFegley/Downloads/TideInformation.csv', dtype = "str", delimiter = ",")
    
    
#We want to create a series of arrays to contain the
#different types of data that is in the CSV file.
#So we create a dayArray, a tidesArray, a timeArray
#and a timeAsValueArray because we know that we want to 
#convert the time into usable data to plot
dataList = dataArray.tolist()
    
tidesArray = np.array([])
    
dayArray = np.array([])

timeArray = np.array([])

timeAsValueArray = np.array([])



#Creating a figure    
fig = plt.figure(figsize = (12,7))


#This for loop is going through the data array and assigning
#values to their correlating array.
for i in dataList:
        
    tidesArray = np.append(tidesArray, float(i[2]), axis = None)
        
    dayArray =np.append(dayArray, int(i[0]), axis = None)
    
    timeArray = np.append(timeArray, i[1], axis = None)

    
    
#Here we want to take the data from our timeArray and convert
#the time into data that we can use, like a float. So we replace
#the colons with periods and create floats
for i in timeArray:
    time = float(i.replace(':', "."))
    timeAsValueArray = np.append(timeAsValueArray, time)
    
print(f"Time As Value Array: {timeAsValueArray}")
     
    
#Creating a singleDayArray in case we don't need repeats
#of days
singleDayArray = dayArray[0::2]

print(f"Time Array: {timeArray}")
    
    
#Calculate the mean of the tides
meanTides = np.mean(tidesArray)
meanTides = "{:.2f}".format(meanTides)
    
#Calculate the variation of the tides
varTides = np.var(tidesArray)
varTides = "{:.2f}".format(varTides)
    
#Calculate the standard deviation of the tides
standTides = np.std(tidesArray)
standTides = "{:.2f}".format(standTides)
    
print(f"The mean of the tides is: {meanTides}")
    
print(f"The variation of the tides is: {varTides}")
    
print(f"The standard deviation of the tides is {standTides}")



#Worked with Professor Brant during office hours about 
#obtaining the right amplitude for the data. So this is
#how I practiced getting the correct amplitudes of the
#tidesArray
tideAmplitude = np.fabs(tidesArray - np.mean(tidesArray))
print(f"Tide Amplitude: {tideAmplitude}")



# print(f"F1 Value: {f1} F2 Value: {f2} P1 Value: {p1} P2 Value: {p2}" )

# params,params_cov = optimize.curve_fit(bestFit, dayArray, tidesArray)

# print(f"Params: {params}")



a_fit, cov = optimize.curve_fit(fitCurve, dayArray, tideAmplitude)
print(f"a_fit: {a_fit}")
        
plt.plot(dayArray, tidesArray,"b-o", label = 'Tide Data')

# plt.plot(dayArray, tideAmplitude, 'r')


#Creating arrays for 2 week and 4 week tide cycles.
#This was practice to see if this data was going to be used 
#in the bestFitCurve function, but this data did not work
#properly.
cycle14 = np.array(tidesArray[0:28])

cycle28 = np.array(tidesArray[0:56])

cycle14Days = np.array(dayArray[0:28])

cycle28Days = np.array(dayArray[0:56])

print(f"Cycle 14: {cycle14}")

print(f"Cycle 28: {cycle28}")



#Getting the amplitudes of the 2 week and 4 week tide cycles.
cycle14Amplitude = np.fabs(cycle14 - np.mean(cycle14))

cycle28Amplitude = np.fabs(cycle28 - np.mean(cycle28))

print(f"Cycle 14 Amplitude: {cycle14Amplitude}")

print(f"Cycle 28 Amplitude: {cycle28Amplitude}")

# b_fit, cov = optimize.curve_fit(fitCurve, cycle14Days, cycle14Amplitude)
# print(f"b_fit: {b_fit}")

# c_fit, cov = optimize.curve_fit(fitCurve, cycle28Days, cycle28Amplitude)
# print(f"c_fit: {c_fit}")




#This ended up being the correct curve_fit mathematical
#function to use
#*************************************************
#Best Fit Curve Function
def bestFitCurve(x, a, b, c, d, e):
    return a*np.sin(x/b) * np.sin(x/c) + (x/d) + e
#*************************************************

popt, cov = optimize.curve_fit(bestFitCurve, timeAsValueArray, tidesArray)
print(f"Popt: {popt}")


plt.plot(dayArray, bestFitCurve(timeAsValueArray, *popt), color = 'purple', label = "Best Fit")

# plt.plot(cycle14Days, cycle14Amplitude, color = 'green')

# plt.plot(cycle28Days, cycle28Amplitude, color = 'purple')

# plt.plot(dayArray, bestFit(dayArray, A1, f1, p1, A2, f2, p2, meanTides))

# print(type(A1), type(f1), type(p1), type(A2), type(f2), type(p2), type(C), type(t))

plt.xlabel("Days")

plt.ylabel("Tide Height")

plt.legend()
    
plt.show()


#Calculating the residual of the tide by calling the
#bestFitCurve function that we created earlier
tideRes = tidesArray - bestFitCurve(timeAsValueArray, *popt)

plt.plot(tideRes)

plt.xlabel("Residuals of Tide Array")

plt.ylabel("Value of Residual")
# Out:
# Time As Value Array: [ 8.07 15.37  8.55 16.25  9.45 17.14 10.35 18.   11.28 18.46 12.22 19.31
#  13.24 20.16  3.22 21.01  4.07 21.46  4.5  11.58  5.31 12.56  6.08 13.45
#   6.47 14.25  7.22 15.    7.59 15.34  8.34 16.08  9.1  16.41  9.45 17.12
#  10.21 17.45 10.57 18.15 11.38 18.48 12.25 19.2   2.22 19.52  2.58 20.3
#   3.37 10.44  4.23 11.55  5.15 12.57  6.09 13.5   7.05 14.39  7.58 15.27
#   8.5  16.1   9.4  16.52 10.3  17.34 11.19 18.12 12.1  18.49  1.32 19.24
#   2.13 20.    2.54  9.54  3.39 11.15  4.29 12.22  5.21 13.14]
# Time Array: ['8:07' '15:37' '8:55' '16:25' '9:45' '17:14' '10:35' '18:00' '11:28'
#  '18:46' '12:22' '19:31' '13:24' '20:16' '3:22' '21:01' '4:07' '21:46'
#  '4:50' '11:58' '5:31' '12:56' '6:08' '13:45' '6:47' '14:25' '7:22'
#  '15:00' '7:59' '15:34' '8:34' '16:08' '9:10' '16:41' '9:45' '17:12'
#  '10:21' '17:45' '10:57' '18:15' '11:38' '18:48' '12:25' '19:20' '2:22'
#  '19:52' '2:58' '20:30' '3:37' '10:44' '4:23' '11:55' '5:15' '12:57'
#  '6:09' '13:50' '7:05' '14:39' '7:58' '15:27' '8:50' '16:10' '9:40'
#  '16:52' '10:30' '17:34' '11:19' '18:12' '12:10' '18:49' '1:32' '19:24'
#  '2:13' '20:00' '2:54' '9:54' '3:39' '11:15' '4:29' '12:22' '5:21' '13:14']
# The mean of the tides is: 2.48
# The variation of the tides is: 5.67
# The standard deviation of the tides is 2.38
# Tide Amplitude: [4.09170732 2.86829268 2.90170732 4.21829268 2.78170732 3.83829268
#  1.65170732 3.62829268 1.00170732 4.08829268 0.14170732 2.42829268
#  0.64829268 1.46829268 1.09170732 1.74829268 2.06170732 0.30829268
#  1.28170732 0.40170732 1.42170732 0.55829268 2.25170732 0.73829268
#  3.18170732 1.68829268 2.85170732 2.51829268 2.75170732 3.59829268
#  4.19170732 3.08829268 2.26170732 3.40829268 2.21170732 3.76829268
#  1.72170732 2.25829268 1.20170732 2.21829268 0.00829268 2.11829268
#  0.11170732 1.48829268 1.62170732 0.60829268 0.69170732 0.87829268
#  1.23170732 0.62170732 1.56170732 0.01170732 1.59170732 0.29829268
#  3.45170732 1.77829268 4.41170732 2.26829268 4.24170732 2.25829268
#  4.29170732 4.15829268 3.29170732 3.79829268 1.87170732 3.20829268
#  1.75170732 2.85829268 0.23829268 3.08829268 0.97170732 2.93829268
#  1.65170732 1.26829268 0.86170732 0.10170732 0.84170732 0.78170732
#  2.73170732 0.08829268 2.35170732 0.06829268]
# a_fit: [-0.40897521  0.86097638  2.97887436]
# Cycle 14: [ 6.57 -0.39  5.38 -1.74  5.26 -1.36  4.13 -1.15  3.48 -1.61  2.62  0.05
#   1.83  1.01  3.57  0.73  4.54  2.17  3.76  2.88  3.9   1.92  4.73  1.74
#   5.66  0.79  5.33 -0.04]
# Cycle 28: [ 6.57 -0.39  5.38 -1.74  5.26 -1.36  4.13 -1.15  3.48 -1.61  2.62  0.05
#   1.83  1.01  3.57  0.73  4.54  2.17  3.76  2.88  3.9   1.92  4.73  1.74
#   5.66  0.79  5.33 -0.04  5.23 -1.12  6.67 -0.61  4.74 -0.93  4.69 -1.29
#   4.2   0.22  3.68  0.26  2.47  0.36  2.59  0.99  4.1   1.87  3.17  1.6
#   3.71  3.1   4.04  2.49  4.07  2.18  5.93  0.7 ]
# Cycle 14 Amplitude: [4.22142857 2.73857143 3.03142857 4.08857143 2.91142857 3.70857143
#  1.78142857 3.49857143 1.13142857 3.95857143 0.27142857 2.29857143
#  0.51857143 1.33857143 1.22142857 1.61857143 2.19142857 0.17857143
#  1.41142857 0.53142857 1.55142857 0.42857143 2.38142857 0.60857143
#  3.31142857 1.55857143 2.98142857 2.38857143]
# Cycle 28 Amplitude: [4.16160714 2.79839286 2.97160714 4.14839286 2.85160714 3.76839286
#  1.72160714 3.55839286 1.07160714 4.01839286 0.21160714 2.35839286
#  0.57839286 1.39839286 1.16160714 1.67839286 2.13160714 0.23839286
#  1.35160714 0.47160714 1.49160714 0.48839286 2.32160714 0.66839286
#  3.25160714 1.61839286 2.92160714 2.44839286 2.82160714 3.52839286
#  4.26160714 3.01839286 2.33160714 3.33839286 2.28160714 3.69839286
#  1.79160714 2.18839286 1.27160714 2.14839286 0.06160714 2.04839286
#  0.18160714 1.41839286 1.69160714 0.53839286 0.76160714 0.80839286
#  1.30160714 0.69160714 1.63160714 0.08160714 1.66160714 0.22839286
#  3.52160714 1.70839286]
# Popt: [ 4.87815859e+04 -1.11512514e+01  2.12213476e+04  4.29257831e-01
#  -1.19069099e+00]
# Text(0, 0.5, 'Value of Residual')

# %%
# plt.plot(dayArray, tidesArray,"b-o", label = 'Tide Data')
width = 0.5

histmin = np.floor(min(tidesArray))

histmax = np.ceil(max(tidesArray))

bins = np.arange(histmin, histmax, width)

plt.hist(tideRes, bins = bins, alpha = 0.5, edgecolor = 'black')

plt.axvline(np.std(tidesArray), color = 'red', linestyle = 'dashed', label = f"Standard Deviation: {standTides}")

# plt.text(2.25, 4, f"Standard Deviation: {standTides}", ha = 'center', va = 'center', rotation = 'vertical')

plt.legend()

# %%
plt.plot(dayArray, np.fabs(tidesArray - np.mean(tidesArray)))

# %%
#Calculating the highest tide from the tidesArray
highestTide = np.amax(tidesArray)

#The underwater volcano had an effect of the tides
#so we added the 2ft outlier to the hungaTongaEffect
hungaTongaEffect = highestTide + 2

#From the data, it looks like the tsunami can be measured
#around the timestamp of 13.24 around the 14th day
timeOfTsunami = 13.24

#Calculating the residual from the tsunami
residualOfTsunami = hungaTongaEffect - bestFitCurve(timeOfTsunami, *popt)

#Calculating the standard deviation of the tsunami against the 
#tidesArray data. I had to fill in the numbers because for some reason
#jupyter-notebook was not allowing me to pass te variables meanTides
#and standTides which held the value of the mean of all the tides(2.48) and
#the standard deviations (2.38)
standardDeviationOfTsunami = (float(hungaTongaEffect) - 2.48) / 2.38

#We want to contain the values in histogramResiduals that way
#we can plot the histogram with the correct data
histogramResiduals = np.append(tideRes, residualOfTsunami)

#Plotting the histogram
plt.hist(histogramResiduals)

plt.show()
# Out:
# 2.38
